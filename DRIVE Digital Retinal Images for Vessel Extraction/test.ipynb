# %%
import torch
import torch.nn as nn

from PIL import Image
import numpy as np

import matplotlib.pyplot as plt

# %%
image = np.array(Image.open('./datasets/training/training/images/21_training.png'))

plt.imshow(image)
print(image.shape)
# Out:
# (584, 565, 3)

# %%
testlist = [1,2,3]
print(f"Before: {testlist}")

def change(testlist):
    testlist[0] = 500
print(f"After: {testlist}")
# Out:
# Before: [1, 2, 3]
# After: [1, 2, 3]
