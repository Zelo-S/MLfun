# %% [markdown]
# <h1>Utils</h1>

# %%
from monai.utils import first
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from monai.losses import DiceLoss
from tqdm import tqdm

def dice_metric(predicted, target):
    '''
    In this function we take `predicted` and `target` (label) to calculate the dice coeficient then we use it 
    to calculate a metric value for the training and the validation.
    '''
    dice_value = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
    value = 1 - dice_value(predicted, target).item()
    return value

def calculate_weights(val1, val2):
    '''
    In this function we take the number of the background and the forgroud pixels to return the `weights` 
    for the cross entropy loss values.
    '''
    count = np.array([val1, val2])
    summ = count.sum()
    weights = count/summ
    weights = 1/weights
    summ = weights.sum()
    weights = weights/summ
    return torch.tensor(weights, dtype=torch.float32)

def train(model, data_in, loss, optim, max_epochs, model_dir, test_interval=1 , device=torch.device("cuda:0")):
    best_metric = -1
    best_metric_epoch = -1
    save_loss_train = []
    save_loss_test = []
    save_metric_train = []
    save_metric_test = []
    train_loader, test_loader = data_in
    print("Begin training...")
    print("Trainloader length: ", len(train_loader))
    print("Testloader length: ", len(test_loader))

    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        train_epoch_loss = 0
        train_step = 1
        epoch_metric_train = 0
        for batch_data in train_loader:
            
            train_step += 1
            print("Train step is", train_step)

            volume = batch_data["vol"]
            label = batch_data["seg"]
            label = label != 0
            volume, label = (volume.to(device), label.to(device))

            optim.zero_grad()
            outputs = model(volume)
            
            train_loss = loss(outputs, label)
            
            train_loss.backward()
            optim.step()

            train_epoch_loss += train_loss.item()
            print(
                f"{train_step}/{len(train_loader) // train_loader.batch_size}, "
                f"Train_loss: {train_loss.item():.4f}")

            train_metric = dice_metric(outputs, label)
            epoch_metric_train += train_metric
            print(f'Train_dice: {train_metric:.4f}')

        print('-'*20)

        train_epoch_loss /= train_step
        print(f'Epoch_loss: {train_epoch_loss:.4f}')
        save_loss_train.append(train_epoch_loss)
        np.save(os.path.join(model_dir, 'loss_train.npy'), save_loss_train)
        
        epoch_metric_train /= train_step
        print(f'Epoch_metric: {epoch_metric_train:.4f}')

        save_metric_train.append(epoch_metric_train)
        np.save(os.path.join(model_dir, 'metric_train.npy'), save_metric_train)

        if (epoch + 1) % test_interval == 0:

            model.eval()
            with torch.no_grad():
                test_epoch_loss = 0
                test_metric = 0
                epoch_metric_test = 0
                test_step = 0

                for test_data in test_loader:

                    test_step += 1

                    test_volume = test_data["vol"]
                    test_label = test_data["seg"]
                    test_label = test_label != 0
                    test_volume, test_label = (test_volume.to(device), test_label.to(device),)
                    
                    test_outputs = model(test_volume)
                    
                    test_loss = loss(outputs, test_label)
                    test_epoch_loss += test_loss.item()
                    test_metric = dice_metric(test_outputs, test_label)
                    epoch_metric_test += test_metric
                    
                
                test_epoch_loss /= test_step
                print(f'test_loss_epoch: {test_epoch_loss:.4f}')
                save_loss_test.append(test_epoch_loss)
                np.save(os.path.join(model_dir, 'loss_test.npy'), save_loss_test)

                epoch_metric_test /= test_step
                print(f'test_dice_epoch: {epoch_metric_test:.4f}')
                save_metric_test.append(epoch_metric_test)
                np.save(os.path.join(model_dir, 'metric_test.npy'), save_metric_test)

                if epoch_metric_test > best_metric:
                    best_metric = epoch_metric_test
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(
                        model_dir, "best_metric_model.pth"))
                
                print(
                    f"current epoch: {epoch + 1} current mean dice: {test_metric:.4f}"
                    f"\nbest mean dice: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )


    print(
        f"train completed, best_metric: {best_metric:.4f} "
        f"at epoch: {best_metric_epoch}")


def show_patient(data, SLICE_NUMBER=1, train=True, test=False):
    """
    This function is to show one patient from your datasets, so that you can si if the it is okay or you need 
    to change/delete something.

    `data`: this parameter should take the patients from the data loader, which means you need to can the function
    prepare first and apply the transforms that you want after that pass it to this function so that you visualize 
    the patient with the transforms that you want.
    `SLICE_NUMBER`: this parameter will take the slice number that you want to display/show
    `train`: this parameter is to say that you want to display a patient from the training data (by default it is true)
    `test`: this parameter is to say that you want to display a patient from the testing patients.
    """

    check_patient_train, check_patient_test = data

    view_train_patient = first(check_patient_train)
    view_test_patient = first(check_patient_test)

    
    if train:
        plt.figure("Visualization Train", (12, 6))
        plt.subplot(1, 2, 1)
        plt.title(f"vol {SLICE_NUMBER}")
        plt.imshow(view_train_patient["vol"][0, 0, :, :, SLICE_NUMBER], cmap="gray")

        plt.subplot(1, 2, 2)
        plt.title(f"seg {SLICE_NUMBER}")
        plt.imshow(view_train_patient["seg"][0, 0, :, :, SLICE_NUMBER])
        plt.show()
    
    if test:
        plt.figure("Visualization Test", (12, 6))
        plt.subplot(1, 2, 1)
        plt.title(f"vol {SLICE_NUMBER}")
        plt.imshow(view_test_patient["vol"][0, 0, :, :, SLICE_NUMBER], cmap="gray")

        plt.subplot(1, 2, 2)
        plt.title(f"seg {SLICE_NUMBER}")
        plt.imshow(view_test_patient["seg"][0, 0, :, :, SLICE_NUMBER])
        plt.show()


def calculate_pixels(data):
    val = np.zeros((1, 2))

    for batch in tqdm(data):
        batch_label = batch["seg"] != 0
        _, count = np.unique(batch_label, return_counts=True)

        if len(count) == 1:
            count = np.append(count, 0)
        val += count

    print('The last values:', val)
    return val

# %% [markdown]
# <h1>Preprocessing</h1>

# %%
import os
from glob import glob
import shutil
from tqdm import tqdm
import dicom2nifti
import numpy as np
import nibabel as nib
from monai.transforms import(
    Compose,
    AddChanneld,
    LoadImaged,
    Resized,
    ToTensord,
    Spacingd,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
)
from monai.data import DataLoader, Dataset, CacheDataset
from monai.utils import set_determinism

"""
This file is for preporcessing only, it contains all the functions that you need
to make your data ready for training.

You need to install the required libraries if you do not already have them.

pip install os, ...
"""

def create_groups(in_dir, out_dir, Number_slices):
    '''
    This function is to get the last part of the path so that we can use it to name the folder.
    `in_dir`: the path to your folders that contain dicom files
    `out_dir`: the path where you want to put the converted nifti files
    `Number_slices`: here you put the number of slices that you need for your project and it will 
    create groups with this number.
    '''

    for patient in glob(in_dir + '/*'):
        patient_name = os.path.basename(os.path.normpath(patient))

        # Here we need to calculate the number of folders which mean into how many groups we will divide the number of slices
        number_folders = int(len(glob(patient + '/*')) / Number_slices)

        for i in range(number_folders):
            output_path = os.path.join(out_dir, patient_name + '_' + str(i))
            os.mkdir(output_path)

            # Move the slices into a specific folder so that you will save memory in your desk
            for i, file in enumerate(glob(patient + '/*')):
                if i == Number_slices + 1:
                    break
                
                shutil.move(file, output_path)


def dcm2nifti(in_dir, out_dir):
    '''
    This function will be used to convert dicoms into nifti files after creating the groups with 
    the number of slices that you want.
    `in_dir`: the path to the folder where you have all the patients (folder of all the groups).
    `out_dir`: the path to the output, which means where you want to save the converted nifties.
    '''

    for folder in tqdm(glob(in_dir + '/*')):
        patient_name = os.path.basename(os.path.normpath(folder))
        dicom2nifti.dicom_series_to_nifti(folder, os.path.join(out_dir, patient_name + '.nii.gz'))


def find_empy(in_dir):
    '''
    This function will help you to find the empty volumes that you may not need for your training
    so instead of opening all the files and search for the empty ones, them use this function to make it quick.
    '''
    
    list_patients = []
    for patient in glob(os.path.join(in_dir, '*')):
        img = nib.load(patient)

        if len(np.unique(img.get_fdata())) > 2:
            print(os.path.basename(os.path.normpath(patient)))
            list_patients.append(os.path.basename(os.path.normpath(patient)))
    
    return list_patients


def prepare(in_dir, pixdim=(1.5, 1.5, 1.0), a_min=-200, a_max=200, spatial_size=[128,128,64], cache=False):

    """
    This function is for preprocessing, it contains only the basic transforms, but you can add more operations that you 
    find in the Monai documentation.
    https://monai.io/docs.html
    """
    print("Preparing...")

    set_determinism(seed=0)

    path_train_volumes = sorted(glob(os.path.join(in_dir, "TrainVolumes", "*.nii.gz")))
    path_train_segmentation = sorted(glob(os.path.join(in_dir, "TrainSegmentation", "*.nii.gz")))

    path_test_volumes = sorted(glob(os.path.join(in_dir, "ValidationVolumes", "*.nii.gz")))
    path_test_segmentation = sorted(glob(os.path.join(in_dir, "ValidationSegmentation", "*.nii.gz")))
    

    '''DEBUG'''
    print(f"Length of path_train_volumes: {len(path_train_volumes)}")    
    print(f"Length of path_train_segmentation: {len(path_train_segmentation)}")    

    print(f"Length of path_test_volumes: {len(path_test_volumes)}")    
    print(f"Length of path_test_segmentation: {len(path_test_segmentation)}")    
    '''DEBUG'''


    train_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in zip(path_train_volumes, path_train_segmentation)]
    test_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in zip(path_test_volumes, path_test_segmentation)]

    train_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            AddChanneld(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max, b_min=0.0, b_max=1.0, clip=True), 
            CropForegroundd(keys=["vol", "seg"], source_key="vol"),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),   
            ToTensord(keys=["vol", "seg"]),

        ]
    )

    test_transforms = Compose(
        [
            LoadImaged(keys=["vol", "seg"]),
            AddChanneld(keys=["vol", "seg"]),
            Spacingd(keys=["vol", "seg"], pixdim=pixdim, mode=("bilinear", "nearest")),
            Orientationd(keys=["vol", "seg"], axcodes="RAS"),
            ScaleIntensityRanged(keys=["vol"], a_min=a_min, a_max=a_max,b_min=0.0, b_max=1.0, clip=True), 
            CropForegroundd(keys=['vol', 'seg'], source_key='vol'),
            Resized(keys=["vol", "seg"], spatial_size=spatial_size),   
            ToTensord(keys=["vol", "seg"]),

            
        ]
    )


    if cache:
        train_ds = CacheDataset(data=train_files, transform=train_transforms,cache_rate=1.0)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = CacheDataset(data=test_files, transform=test_transforms, cache_rate=1.0)
        test_loader = DataLoader(test_ds, batch_size=1)
        print("Preparing done.")

        return train_loader, test_loader

    else:
        train_ds = Dataset(data=train_files, transform=train_transforms)
        train_loader = DataLoader(train_ds, batch_size=1)

        test_ds = Dataset(data=test_files, transform=test_transforms)
        test_loader = DataLoader(test_ds, batch_size=1)
        print("Preparing done.")

        return train_loader, test_loader

# %% [markdown]
# <h1>Train</h1>

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.losses import DiceLoss, DiceCELoss

import torch

data_dir = 'D:/MLDatasets/Liver Tumor Segmentation/Task03_Liver/Task03_Liver'
model_dir = 'D:/MLDatasets/Liver Tumor Segmentation/Task03_Liver' 
data_in = prepare(data_dir, cache=True)

device = torch.device("cuda:0")
model = UNet(
    dimensions=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256), 
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

print(f"Length of data: {len(data_in)}")
# Out:
# Preparing...
# Length of path_train_volumes: 105
# Length of path_train_segmentation: 105
# Length of path_test_volumes: 26
# Length of path_test_segmentation: 26
# Loading dataset: 100%|██████████| 105/105 [26:27<00:00, 15.12s/it]
# Loading dataset: 100%|██████████| 26/26 [09:26<00:00, 21.78s/it]
# Preparing done.
# Length of data: 2

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)

train(model, data_in, loss_function, optimizer, 10, model_dir)
# Out:
# Begin training...
# Trainloader length:  105
# Testloader length:  26
# ----------
# epoch 1/10
# Train step is 2
# 2/105, Train_loss: 0.5451
# Train_dice: 0.4549
# Train step is 3
# 3/105, Train_loss: 0.5665
# Train_dice: 0.4335
# Train step is 4
# 4/105, Train_loss: 0.5640
# Train_dice: 0.4360
# Train step is 5
# 5/105, Train_loss: 0.5443
# Train_dice: 0.4557
# Train step is 6
# 6/105, Train_loss: 0.5385
# Train_dice: 0.4615
# Train step is 7
# 7/105, Train_loss: 0.5554
# Train_dice: 0.4446
# Train step is 8
# 8/105, Train_loss: 0.5711
# Train_dice: 0.4289
# Train step is 9
# 9/105, Train_loss: 0.5696
# Train_dice: 0.4304
# Train step is 10
# 10/105, Train_loss: 0.5582
# Train_dice: 0.4418
# Train step is 11
# Train step is 103
# 103/105, Train_loss: 0.4951
# Train_dice: 0.5049
# Train step is 104
# 104/105, Train_loss: 0.5001
# Train_dice: 0.4999
# Train step is 105
# 105/105, Train_loss: 0.5095
# Train_dice: 0.4905
# Train step is 106
# 106/105, Train_loss: 0.5158
# Train_dice: 0.4842
# --------------------
# Epoch_loss: 0.5091
# Epoch_metric: 0.4815
# test_loss_epoch: 0.5418
# test_dice_epoch: 0.4785
# current epoch: 2 current mean dice: 0.5123
# best mean dice: 0.4785 at epoch: 2
# ----------
# epoch 3/10
# Train step is 2
# 2/105, Train_loss: 0.4902
# Train_dice: 0.5098
# Train step is 3
# 3/105, Train_loss: 0.5268
# Train_dice: 0.4732
# Train step is 4
# 4/105, Train_loss: 0.5217
# Train_dice: 0.4783
# Train step is 5
# 5/105, Train_loss: 0.4883
# Train_dice: 0.5117
# Train step is 6
# 6/105, Train_loss: 0.4819
# Train_dice: 0.5181
# Train step is 7
# 7/105, Train_loss: 0.5103
# Train_dice: 0.4897
# Train step is 8
# 8/105, Train_loss: 0.5350
# Train_dice: 0.4650
# Train step is 9
# 9/105, Train_loss: 0.5334
# Train_dice: 0.4666
# Train step is 10
# 10/105, Train_loss: 0.5149
# Train_dice: 0.4851
# Train step is 11
# 11/105, Train_loss: 0.4950
# Train_dice: 0.5050
# Train step is 12
# 12/105, Train_loss: 0.5450
# Train_dice: 0.4550
# Train step is 13
# 13/105, Train_loss: 0.5274
# Train_dice: 0.4726
# Train step is 14
# 14/105, Train_loss: 0.5222
# Train_dice: 0.4778
# Train step is 15
# 15/105, Train_loss: 0.5154
# Train_dice: 0.4846
# Train step is 16
# 16/105, Train_loss: 0.5278
# Train_dice: 0.4722
# Train step is 17
# 17/105, Train_loss: 0.5513
# Train_dice: 0.4487
# Train step is 18
# 18/105, Train_loss: 0.5069
# Train_dice: 0.4931
# Train step is 19
# 19/105, Train_loss: 0.5174
# Train_dice: 0.4826
# Train step is 20
# 20/105, Train_loss: 0.5095
# Train_dice: 0.4905
# Train step is 21
# 21/105, Train_loss: 0.5043
# Train_dice: 0.4957
# Train step is 22
# 22/105, Train_loss: 0.5640
# Train_dice: 0.4360
# Train step is 23
# 23/105, Train_loss: 0.5116
# Train_dice: 0.4884
# Train step is 24
# 24/105, Train_loss: 0.5067
# Train_dice: 0.4933
# Train step is 25
# 25/105, Train_loss: 0.5158
# Train_dice: 0.4842
# Train step is 26
# 26/105, Train_loss: 0.5321
# Train_dice: 0.4679
# Train step is 27
# 27/105, Train_loss: 0.5350
# Train_dice: 0.4650
# Train step is 28
# 28/105, Train_loss: 0.4029
# Train_dice: 0.5971
# Train step is 29
# 29/105, Train_loss: 0.4654
# Train_dice: 0.5346
# Train step is 30
# 30/105, Train_loss: 0.5219
# Train_dice: 0.4781
# Train step is 31
# 31/105, Train_loss: 0.4610
# Train_dice: 0.5390
# Train step is 32
# 32/105, Train_loss: 0.4552
# Train_dice: 0.5448
# Train step is 33
# 33/105, Train_loss: 0.4281
# Train_dice: 0.5719
# Train step is 34
# 34/105, Train_loss: 0.4416
# Train_dice: 0.5358
# Train step is 7
# 7/105, Train_loss: 0.4959
# Train_dice: 0.5041
# Train step is 8
# 8/105, Train_loss: 0.5234
# Train_dice: 0.4766
# Train step is 9
# 9/105, Train_loss: 0.5220
# Train_dice: 0.4780
# Train step is 10
# 10/105, Train_loss: 0.5007
# Train_dice: 0.4993
# Train step is 11
# 11/105, Train_loss: 0.4785
# Train_dice: 0.5215
# Train step is 12
# 12/105, Train_loss: 0.5350
# Train_dice: 0.4650
# Train step is 13
# 13/105, Train_loss: 0.5150
# Train_dice: 0.4850
# Train step is 14
# 14/105, Train_loss: 0.5092
# Train_dice: 0.4908
# Train step is 15
# 15/105, Train_loss: 0.5021
# Train_dice: 0.4979
# Train step is 16
# 16/105, Train_loss: 0.5155
# Train_dice: 0.4845
# Train step is 17
# 17/105, Train_loss: 0.5422
# Train_dice: 0.4578
# Train step is 18
# 18/105, Train_loss: 0.4922
# Train_dice: 0.5078
# Train step is 19
# 19/105, Train_loss: 0.5042
# Train_dice: 0.4958
# Train step is 20
# 20/105, Train_loss: 0.4954
# Train_dice: 0.5046
# Train step is 21
# 21/105, Train_loss: 0.4892
# Train_dice: 0.5108
# Train step is 22
# 22/105, Train_loss: 0.5568
# Train_dice: 0.4432
# Train step is 23
# 23/105, Train_loss: 0.4974
# Train_dice: 0.5026
# Train step is 24
# 24/105, Train_loss: 0.4923
# Train_dice: 0.5077
# Train step is 25
# 25/105, Train_loss: 0.5030
# Train_dice: 0.4970
# Train step is 26
# 26/105, Train_loss: 0.5210
# Train_dice: 0.4790
# Train step is 27
# 27/105, Train_loss: 0.5244
# Train_dice: 0.4756
# Train step is 28
# 28/105, Train_loss: 0.3789
# Train_dice: 0.6211
# Train step is 29
# 29/105, Train_loss: 0.4480
# Train_dice: 0.5520
# Train step is 30
# 30/105, Train_loss: 0.5093
# Train_dice: 0.4907
# Train step is 31
# 31/105, Train_loss: 0.4436
# Train_dice: 0.5564
# Train step is 32
# 32/105, Train_loss: 0.4368
# Train_dice: 0.5632
# Train step is 33
# 33/105, Train_loss: 0.4078
# Train_dice: 0.5922
# Train step is 34
# 34/105, Train_loss: 0.4223
# Train_dice: 0.5777
# Train step is 35
# 35/105, Train_loss: 0.4416
# Train_dice: 0.5584
# Train step is 36
# 36/105, Train_loss: 0.3432
# Train_dice: 0.6568
# Train step is 37
# 37/105, Train_loss: 0.4316
# Train_dice: 0.5684
# Train step is 38
# 38/105, Train_loss: 0.3957
# Train_dice: 0.6043
# Train step is 39
# 39/105, Train_loss: 0.4073
# Train_dice: 0.5927
# Train step is 40
# 40/105, Train_loss: 0.4217
# Train_dice: 0.5783
# Train step is 41
# 41/105, Train_loss: 0.4977
# Train_dice: 0.5023
# Train step is 42
# 42/105, Train_loss: 0.4024
# Train_dice: 0.5976
# Train step is 43
# 43/105, Train_loss: 0.3974
# Train_dice: 0.6026
# Train step is 44
# 44/105, Train_loss: 0.4210
# Train_dice: 0.5790
# Train step is 45
# 45/105, Train_loss: 0.4049
# Train_dice: 0.5951
# Train step is 46
# 46/105, Train_loss: 0.3888
# Train_dice: 0.5160
# Train step is 87
# 87/105, Train_loss: 0.4805
# Train_dice: 0.5195
# Train step is 88
# 88/105, Train_loss: 0.4463
# Train_dice: 0.5537
# Train step is 89
# 89/105, Train_loss: 0.5236
# Train_dice: 0.4764
# Train step is 90
# 90/105, Train_loss: 0.4834
# Train_dice: 0.5166
# Train step is 91
# 91/105, Train_loss: 0.4393
# Train_dice: 0.5607
# Train step is 92
# 92/105, Train_loss: 0.4735
# Train_dice: 0.5265
# Train step is 93
# 93/105, Train_loss: 0.5213
# Train_dice: 0.4787
# Train step is 94
# 94/105, Train_loss: 0.5205
# Train_dice: 0.4795
# Train step is 95
# 95/105, Train_loss: 0.5184
# Train_dice: 0.4816
# Train step is 96
# 96/105, Train_loss: 0.5135
# Train_dice: 0.4865
# Train step is 97
# 97/105, Train_loss: 0.5148
# Train_dice: 0.4852
# Train step is 98
# 98/105, Train_loss: 0.5214
# Train_dice: 0.4786
# Train step is 99
# 99/105, Train_loss: 0.5184
# Train_dice: 0.4816
# Train step is 100
# 100/105, Train_loss: 0.4892
# Train_dice: 0.5108
# Train step is 101
# 101/105, Train_loss: 0.5287
# Train_dice: 0.4713
# Train step is 102
# 102/105, Train_loss: 0.5121
# Train_dice: 0.4879
# Train step is 103
# 103/105, Train_loss: 0.4652
# Train_dice: 0.5348
# Train step is 104
# 104/105, Train_loss: 0.4719
# Train_dice: 0.5281
# Train step is 105
# 105/105, Train_loss: 0.4837
# Train_dice: 0.5163
# Train step is 106
# 106/105, Train_loss: 0.4915
# Train_dice: 0.5085
# --------------------
# Epoch_loss: 0.4784
# Epoch_metric: 0.5122
# test_loss_epoch: 0.5304
# test_dice_epoch: 0.5026
# current epoch: 4 current mean dice: 0.5401
# best mean dice: 0.5026 at epoch: 4
# ----------
# epoch 5/10
# Train step is 2
# 2/105, Train_loss: 0.4595
# Train_dice: 0.5405
# Train step is 3
# 3/105, Train_loss: 0.5036
# Train_dice: 0.4964
# Train step is 4
# 4/105, Train_loss: 0.4980
# Train_dice: 0.5020
# Train step is 5
# 5/105, Train_loss: 0.4584
# Train_dice: 0.5416
# Train step is 6
# 6/105, Train_loss: 0.4505
# Train_dice: 0.5495
# Train step is 7
# 7/105, Train_loss: 0.4847
# Train_dice: 0.5153
# Train step is 8
# 8/105, Train_loss: 0.5144
# Train_dice: 0.4856
# Train step is 9
# 9/105, Train_loss: 0.5128
# Train_dice: 0.4872
# Train step is 10
# 10/105, Train_loss: 0.4895
# Train_dice: 0.5105
# Train step is 11
# 11/105, Train_loss: 0.4656
# Train_dice: 0.5344
# Train step is 12
# 12/105, Train_loss: 0.5271
# Train_dice: 0.4729
# Train step is 13
# 13/105, Train_loss: 0.5054
# Train_dice: 0.4946
# Train step is 14
# 14/105, Train_loss: 0.4989
# Train_dice: 0.5011
# Train step is 15
# 15/105, Train_loss: 0.4919
# Train_dice: 0.5081
# Train step is 16
# 16/105, Train_loss: 0.5058
# Train_dice: 0.4942
# Train step is 17
# 17/105, Train_loss: 0.5350
# Train_dice: 0.4650
# Train step is 18
# 18/105, Train_loss: 0.4809
# Train_dice: 0.5191
# Train step is 19
# 19/105, Train_loss: 0.4941
# Train_dice: 0.5059
# Train step is 20
# 20/105, Train_loss: 0.4847
# Train_dice: 0.5153
# Train step is 21
# 21/105, Train_loss: 0.4779
# Train_dice: 0.5221
# Train step is 22
# 22/105, Train_loss: 0.5508
# Train_dice: 0.4492
# Train step is 23
# 23/105, Train_loss: 0.4863
# Train_dice: 0.5137
# Train step is 24
# 24/105, Train_loss: 0.4814
# Train_dice: 0.5186
# Train step is 25
# 25/105, Train_loss: 0.4931
# Train_dice: 0.5069
# Train step is 26
# 26/105, Train_loss: 0.5124
# Train_dice: 0.4876
# Train step is 27
# 27/105, Train_loss: 0.5161
# Train_dice: 0.4839
# Train step is 28
# 28/105, Train_loss: 0.3599
# Train_dice: 0.6401
# Train step is 29
# 29/105, Train_loss: 0.4355
# Train_dice: 0.5645
# Train step is 30
# 30/105, Train_loss: 0.4997
# Train_dice: 0.5003
# Train step is 31
# 31/105, Train_loss: 0.4302
# Train_dice: 0.5698
# Train step is 32
# 32/105, Train_loss: 0.4236
# Train_dice: 0.5764
# Train step is 33
# 33/105, Train_loss: 0.3926
# Train_dice: 0.6074
# Train step is 34
# 34/105, Train_loss: 0.4080
# Train_dice: 0.5920
# Train step is 35
# 35/105, Train_loss: 0.4291
# Train_dice: 0.5709
# Train step is 36
# 36/105, Train_loss: 0.3265
# Train_dice: 0.6735
# Train step is 37
# 37/105, Train_loss: 0.4183
# Train_dice: 0.5817
# Train step is 38
# 38/105, Train_loss: 0.3802
# Train_dice: 0.6198
# Train step is 39
# 39/105, Train_loss: 0.3928
# Train_dice: 0.6072
# Train step is 40
# 40/105, Train_loss: 0.4084
# Train_dice: 0.5916
# Train step is 41
# 41/105, Train_loss: 0.4879
# Train_dice: 0.5121
# Train step is 42
# 42/105, Train_loss: 0.3875
# Train_dice: 0.6125
# Train step is 43
# 43/105, Train_loss: 0.3831
# Train_dice: 0.6169
# Train step is 44
# 44/105, Train_loss: 0.4079
# Train_dice: 0.5921
# Train step is 45
# 45/105, Train_loss: 0.3896
# Train_dice: 0.6104
# Train step is 46
# 46/105, Train_loss: 0.3738
# Train_dice: 0.6262
# Train step is 47
# 47/105, Train_loss: 0.3798
# Train_dice: 0.6202
# Train step is 48
# 48/105, Train_loss: 0.5034
# Train_dice: 0.4966
# Train step is 49
# 49/105, Train_loss: 0.4911
# Train_dice: 0.5089
# Train step is 50
# 50/105, Train_loss: 0.5048
# Train_dice: 0.4952
# Train step is 51
# 51/105, Train_loss: 0.5242
# Train_dice: 0.4758
# Train step is 52
# 52/105, Train_loss: 0.5180
# Train_dice: 0.4820
# Train step is 53
# 53/105, Train_loss: 0.5165
# Train_dice: 0.4835
# Train step is 54
# 54/105, Train_loss: 0.5201
# Train_dice: 0.4799
# Train step is 55
# 55/105, Train_loss: 0.5219
# Train_dice: 0.4781
# Train step is 56
# 56/105, Train_loss: 0.4982
# Train_dice: 0.5018
# Train step is 57
# 57/105, Train_loss: 0.4873
# Train_dice: 0.5127
# Train step is 58
# 58/105, Train_loss: 0.4460
# Train_dice: 0.5540
# Train step is 59
# 59/105, Train_loss: 0.4710
# Train_dice: 0.5290
# Train step is 60
# 60/105, Train_loss: 0.4502
# Train_dice: 0.5498
# Train step is 61
# 61/105, Train_loss: 0.4781
# Train_dice: 0.5219
# Train step is 62
# 62/105, Train_loss: 0.4785
# Train_dice: 0.5215
# Train step is 63
# 63/105, Train_loss: 0.4949
# Train_dice: 0.5051
# Train step is 64
# 64/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 65
# 65/105, Train_loss: 0.4857
# Train_dice: 0.5143
# Train step is 66
# 66/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 67
# 67/105, Train_loss: 0.4874
# Train_dice: 0.5126
# Train step is 68
# 68/105, Train_loss: 0.4536
# Train_dice: 0.5464
# Train step is 69
# 69/105, Train_loss: 0.4879
# Train_dice: 0.5121
# Train step is 70
# 70/105, Train_loss: 0.4660
# Train_dice: 0.5340
# Train step is 71
# 71/105, Train_loss: 0.4855
# Train_dice: 0.5145
# Train step is 72
# 72/105, Train_loss: 0.5040
# Train_dice: 0.4960
# Train step is 73
# 73/105, Train_loss: 0.4845
# Train_dice: 0.5155
# Train step is 74
# 74/105, Train_loss: 0.4981
# Train_dice: 0.5019
# Train step is 75
# 75/105, Train_loss: 0.4752
# Train_dice: 0.5248
# Train step is 76
# 76/105, Train_loss: 0.4446
# Train_dice: 0.5554
# Train step is 77
# 77/105, Train_loss: 0.4126
# Train_dice: 0.5874
# Train step is 78
# 78/105, Train_loss: 0.4980
# Train_dice: 0.5020
# Train step is 79
# 79/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 80
# 80/105, Train_loss: 0.4711
# Train_dice: 0.5289
# Train step is 81
# 81/105, Train_loss: 0.4533
# Train_dice: 0.5467
# Train step is 82
# 82/105, Train_loss: 0.4881
# Train_dice: 0.5119
# Train step is 83
# 83/105, Train_loss: 0.4925
# Train_dice: 0.5075
# Train step is 84
# 84/105, Train_loss: 0.5114
# Train_dice: 0.4886
# Train step is 85
# 85/105, Train_loss: 0.4953
# Train_dice: 0.5047
# Train step is 86
# 86/105, Train_loss: 0.4751
# Train_dice: 0.5249
# Train step is 87
# 87/105, Train_loss: 0.4712
# Train_dice: 0.5288
# Train step is 88
# 88/105, Train_loss: 0.4353
# Train_dice: 0.5647
# Train step is 89
# 89/105, Train_loss: 0.5167
# Train_dice: 0.4833
# Train step is 90
# 90/105, Train_loss: 0.4740
# Train_dice: 0.5260
# Train step is 91
# 91/105, Train_loss: 0.4281
# Train_dice: 0.5719
# Train step is 92
# 92/105, Train_loss: 0.4637
# Train_dice: 0.5363
# Train step is 93
# 93/105, Train_loss: 0.5144
# Train_dice: 0.4856
# Train step is 94
# 94/105, Train_loss: 0.5136
# Train_dice: 0.4864
# Train step is 95
# 95/105, Train_loss: 0.5113
# Train_dice: 0.4887
# Train step is 96
# 96/105, Train_loss: 0.5060
# Train_dice: 0.4940
# Train step is 97
# 97/105, Train_loss: 0.5073
# Train_dice: 0.4927
# Train step is 98
# 98/105, Train_loss: 0.5145
# Train_dice: 0.4855
# Train step is 99
# 99/105, Train_loss: 0.5113
# Train_dice: 0.4887
# Train step is 100
# 100/105, Train_loss: 0.4804
# Train_dice: 0.5196
# Train step is 101
# 101/105, Train_loss: 0.5225
# Train_dice: 0.4775
# Train step is 102
# 102/105, Train_loss: 0.5049
# Train_dice: 0.4951
# Train step is 103
# 103/105, Train_loss: 0.4553
# Train_dice: 0.5447
# Train step is 104
# 104/105, Train_loss: 0.4627
# Train_dice: 0.5373
# Train step is 105
# 105/105, Train_loss: 0.4751
# Train_dice: 0.5249
# Train step is 106
# 106/105, Train_loss: 0.4835
# Train_dice: 0.5165
# --------------------
# Epoch_loss: 0.4683
# Epoch_metric: 0.5222
# test_loss_epoch: 0.5264
# test_dice_epoch: 0.5106
# current epoch: 5 current mean dice: 0.5492
# best mean dice: 0.5106 at epoch: 5
# ----------
# epoch 6/10
# Train step is 2
# 2/105, Train_loss: 0.4495
# Train_dice: 0.5505
# Train step is 3
# 3/105, Train_loss: 0.4956
# Train_dice: 0.5044
# Train step is 4
# 4/105, Train_loss: 0.4899
# Train_dice: 0.5101
# Train step is 5
# 5/105, Train_loss: 0.4484
# Train_dice: 0.5516
# Train step is 6
# 6/105, Train_loss: 0.4399
# Train_dice: 0.5601
# Train step is 7
# 7/105, Train_loss: 0.4759
# Train_dice: 0.5241
# Train step is 8
# 8/105, Train_loss: 0.5074
# Train_dice: 0.4926
# Train step is 9
# 9/105, Train_loss: 0.5055
# Train_dice: 0.4945
# Train step is 10
# 10/105, Train_loss: 0.4809
# Train_dice: 0.5191
# Train step is 11
# 11/105, Train_loss: 0.4558
# Train_dice: 0.5442
# Train step is 12
# 12/105, Train_loss: 0.5208
# Train_dice: 0.4792
# Train step is 13
# 13/105, Train_loss: 0.4976
# Train_dice: 0.5024
# Train step is 14
# 14/105, Train_loss: 0.4907
# Train_dice: 0.5093
# Train step is 15
# 15/105, Train_loss: 0.4839
# Train_dice: 0.5161
# Train step is 16
# 16/105, Train_loss: 0.4982
# Train_dice: 0.5018
# Train step is 17
# 17/105, Train_loss: 0.5292
# Train_dice: 0.4708
# Train step is 18
# 18/105, Train_loss: 0.4721
# Train_dice: 0.5279
# Train step is 19
# 19/105, Train_loss: 0.4861
# Train_dice: 0.5139
# Train step is 20
# 20/105, Train_loss: 0.4764
# Train_dice: 0.5236
# Train step is 21
# 21/105, Train_loss: 0.4693
# Train_dice: 0.5307
# Train step is 22
# 22/105, Train_loss: 0.5460
# Train_dice: 0.4540
# Train step is 23
# 23/105, Train_loss: 0.4776
# Train_dice: 0.5224
# Train step is 24
# 24/105, Train_loss: 0.4728
# Train_dice: 0.5272
# Train step is 25
# 25/105, Train_loss: 0.4852
# Train_dice: 0.5148
# Train step is 26
# 26/105, Train_loss: 0.5055
# Train_dice: 0.4945
# Train step is 27
# 27/105, Train_loss: 0.5095
# Train_dice: 0.4905
# Train step is 28
# 28/105, Train_loss: 0.3456
# Train_dice: 0.6544
# Train step is 29
# 29/105, Train_loss: 0.4259
# Train_dice: 0.5741
# Train step is 30
# 30/105, Train_loss: 0.4920
# Train_dice: 0.5080
# Train step is 31
# 31/105, Train_loss: 0.4193
# Train_dice: 0.5807
# Train step is 32
# 32/105, Train_loss: 0.4133
# Train_dice: 0.5867
# Train step is 33
# 33/105, Train_loss: 0.3804
# Train_dice: 0.6196
# Train step is 34
# 34/105, Train_loss: 0.3971
# Train_dice: 0.6029
# Train step is 35
# 35/105, Train_loss: 0.4193
# Train_dice: 0.5807
# Train step is 36
# 36/105, Train_loss: 0.3138
# Train_dice: 0.6862
# Train step is 37
# 37/105, Train_loss: 0.4081
# Train_dice: 0.5919
# Train step is 38
# 38/105, Train_loss: 0.3686
# Train_dice: 0.6314
# Train step is 39
# 39/105, Train_loss: 0.3813
# Train_dice: 0.6187
# Train step is 40
# 40/105, Train_loss: 0.3979
# Train_dice: 0.6021
# Train step is 41
# 41/105, Train_loss: 0.4801
# Train_dice: 0.5199
# Train step is 42
# 42/105, Train_loss: 0.3756
# Train_dice: 0.6244
# Train step is 43
# 43/105, Train_loss: 0.3722
# Train_dice: 0.6278
# Train step is 44
# 44/105, Train_loss: 0.3975
# Train_dice: 0.6025
# Train step is 45
# 45/105, Train_loss: 0.3776
# Train_dice: 0.6224
# Train step is 46
# 46/105, Train_loss: 0.3622
# Train_dice: 0.6378
# Train step is 47
# 47/105, Train_loss: 0.3686
# Train_dice: 0.6314
# Train step is 48
# 48/105, Train_loss: 0.4964
# Train_dice: 0.5036
# Train step is 49
# 49/105, Train_loss: 0.4835
# Train_dice: 0.5165
# Train step is 50
# 50/105, Train_loss: 0.4978
# Train_dice: 0.5022
# Train step is 51
# 51/105, Train_loss: 0.5182
# Train_dice: 0.4818
# Train step is 52
# 52/105, Train_loss: 0.5116
# Train_dice: 0.4884
# Train step is 53
# 53/105, Train_loss: 0.5103
# Train_dice: 0.4897
# Train step is 54
# 54/105, Train_loss: 0.5141
# Train_dice: 0.4859
# Train step is 55
# 55/105, Train_loss: 0.5159
# Train_dice: 0.4841
# Train step is 56
# 56/105, Train_loss: 0.4912
# Train_dice: 0.5088
# Train step is 57
# 57/105, Train_loss: 0.4796
# Train_dice: 0.5204
# Train step is 58
# 58/105, Train_loss: 0.4366
# Train_dice: 0.5634
# Train step is 59
# 59/105, Train_loss: 0.4629
# Train_dice: 0.5371
# Train step is 60
# 60/105, Train_loss: 0.4406
# Train_dice: 0.5594
# Train step is 61
# 61/105, Train_loss: 0.4702
# Train_dice: 0.5298
# Train step is 62
# 62/105, Train_loss: 0.4703
# Train_dice: 0.5297
# Train step is 63
# 63/105, Train_loss: 0.4876
# Train_dice: 0.5124
# Train step is 64
# 64/105, Train_loss: 0.4669
# Train_dice: 0.5331
# Train step is 65
# 65/105, Train_loss: 0.4780
# Train_dice: 0.5220
# Train step is 66
# 66/105, Train_loss: 0.4664
# Train_dice: 0.5336
# Train step is 67
# 67/105, Train_loss: 0.4799
# Train_dice: 0.5201
# Train step is 68
# 68/105, Train_loss: 0.4447
# Train_dice: 0.5553
# Train step is 69
# 69/105, Train_loss: 0.4795
# Train_dice: 0.5205
# Train step is 70
# 70/105, Train_loss: 0.4575
# Train_dice: 0.5425
# Train step is 71
# 71/105, Train_loss: 0.4779
# Train_dice: 0.5221
# Train step is 72
# 72/105, Train_loss: 0.4972
# Train_dice: 0.5028
# Train step is 73
# 73/105, Train_loss: 0.4772
# Train_dice: 0.5228
# Train step is 74
# 74/105, Train_loss: 0.4911
# Train_dice: 0.5089
# Train step is 75
# 75/105, Train_loss: 0.4679
# Train_dice: 0.5321
# Train step is 76
# 76/105, Train_loss: 0.4356
# Train_dice: 0.5644
# Train step is 77
# 77/105, Train_loss: 0.4025
# Train_dice: 0.5975
# Train step is 78
# 78/105, Train_loss: 0.4912
# Train_dice: 0.5088
# Train step is 79
# 79/105, Train_loss: 0.4668
# Train_dice: 0.5332
# Train step is 80
# 80/105, Train_loss: 0.4632
# Train_dice: 0.5368
# Train step is 81
# 81/105, Train_loss: 0.4448
# Train_dice: 0.5552
# Train step is 82
# 82/105, Train_loss: 0.4809
# Train_dice: 0.5191
# Train step is 83
# 83/105, Train_loss: 0.4855
# Train_dice: 0.5145
# Train step is 84
# 84/105, Train_loss: 0.5052
# Train_dice: 0.4948
# Train step is 85
# 85/105, Train_loss: 0.4881
# Train_dice: 0.5119
# Train step is 86
# 86/105, Train_loss: 0.4677
# Train_dice: 0.5323
# Train step is 87
# 87/105, Train_loss: 0.4632
# Train_dice: 0.5368
# Train step is 88
# 88/105, Train_loss: 0.4263
# Train_dice: 0.5737
# Train step is 89
# 89/105, Train_loss: 0.5110
# Train_dice: 0.4890
# Train step is 90
# 90/105, Train_loss: 0.4660
# Train_dice: 0.5340
# Train step is 91
# 91/105, Train_loss: 0.4190
# Train_dice: 0.5810
# Train step is 92
# 92/105, Train_loss: 0.4556
# Train_dice: 0.5444
# Train step is 93
# 93/105, Train_loss: 0.5086
# Train_dice: 0.4914
# Train step is 94
# 94/105, Train_loss: 0.5078
# Train_dice: 0.4922
# Train step is 95
# 95/105, Train_loss: 0.5053
# Train_dice: 0.4947
# Train step is 96
# 96/105, Train_loss: 0.4998
# Train_dice: 0.5002
# Train step is 97
# 97/105, Train_loss: 0.5010
# Train_dice: 0.4990
# Train step is 98
# 98/105, Train_loss: 0.5087
# Train_dice: 0.4913
# Train step is 99
# 99/105, Train_loss: 0.5053
# Train_dice: 0.4947
# Train step is 100
# 100/105, Train_loss: 0.4730
# Train_dice: 0.5270
# Train step is 101
# 101/105, Train_loss: 0.5173
# Train_dice: 0.4827
# Train step is 102
# 102/105, Train_loss: 0.4986
# Train_dice: 0.5014
# Train step is 103
# 103/105, Train_loss: 0.4471
# Train_dice: 0.5529
# Train step is 104
# 104/105, Train_loss: 0.4551
# Train_dice: 0.5449
# Train step is 105
# 105/105, Train_loss: 0.4680
# Train_dice: 0.5320
# Train step is 106
# 106/105, Train_loss: 0.4768
# Train_dice: 0.5232
# --------------------
# Epoch_loss: 0.4602
# Epoch_metric: 0.5304
# test_loss_epoch: 0.5230
# test_dice_epoch: 0.5170
# current epoch: 6 current mean dice: 0.5564
# best mean dice: 0.5170 at epoch: 6
# ----------
# epoch 7/10
# Train step is 2
# 2/105, Train_loss: 0.4415
# Train_dice: 0.5585
# Train step is 3
# 3/105, Train_loss: 0.4890
# Train_dice: 0.5110
# Train step is 4
# 4/105, Train_loss: 0.4829
# Train_dice: 0.5171
# Train step is 5
# 5/105, Train_loss: 0.4402
# Train_dice: 0.5598
# Train step is 6
# 6/105, Train_loss: 0.4314
# Train_dice: 0.5686
# Train step is 7
# 7/105, Train_loss: 0.4684
# Train_dice: 0.5316
# Train step is 8
# 8/105, Train_loss: 0.5014
# Train_dice: 0.4986
# Train step is 9
# 9/105, Train_loss: 0.4995
# Train_dice: 0.5005
# Train step is 10
# 10/105, Train_loss: 0.4737
# Train_dice: 0.5263
# Train step is 11
# 11/105, Train_loss: 0.4477
# Train_dice: 0.5523
# Train step is 12
# 12/105, Train_loss: 0.5154
# Train_dice: 0.4846
# Train step is 13
# 13/105, Train_loss: 0.4909
# Train_dice: 0.5091
# Train step is 14
# 14/105, Train_loss: 0.4837
# Train_dice: 0.5163
# Train step is 15
# 15/105, Train_loss: 0.4773
# Train_dice: 0.5227
# Train step is 16
# 16/105, Train_loss: 0.4917
# Train_dice: 0.5083
# Train step is 17
# 17/105, Train_loss: 0.5242
# Train_dice: 0.4758
# Train step is 18
# 18/105, Train_loss: 0.4646
# Train_dice: 0.5354
# Train step is 19
# 19/105, Train_loss: 0.4793
# Train_dice: 0.5207
# Train step is 20
# 20/105, Train_loss: 0.4695
# Train_dice: 0.5305
# Train step is 21
# 21/105, Train_loss: 0.4622
# Train_dice: 0.5378
# Train step is 22
# 22/105, Train_loss: 0.5419
# Train_dice: 0.4581
# Train step is 23
# 23/105, Train_loss: 0.4702
# Train_dice: 0.5298
# Train step is 24
# 24/105, Train_loss: 0.4654
# Train_dice: 0.5346
# Train step is 25
# 25/105, Train_loss: 0.4786
# Train_dice: 0.5214
# Train step is 26
# 26/105, Train_loss: 0.4998
# Train_dice: 0.5002
# Train step is 27
# 27/105, Train_loss: 0.5039
# Train_dice: 0.4961
# Train step is 28
# 28/105, Train_loss: 0.3345
# Train_dice: 0.6655
# Train step is 29
# 29/105, Train_loss: 0.4178
# Train_dice: 0.5822
# Train step is 30
# 30/105, Train_loss: 0.4856
# Train_dice: 0.5144
# Train step is 31
# 31/105, Train_loss: 0.4104
# Train_dice: 0.5896
# Train step is 32
# 32/105, Train_loss: 0.4049
# Train_dice: 0.5951
# Train step is 33
# 33/105, Train_loss: 0.3704
# Train_dice: 0.6296
# Train step is 34
# 34/105, Train_loss: 0.3882
# Train_dice: 0.6118
# Train step is 35
# 35/105, Train_loss: 0.4110
# Train_dice: 0.5890
# Train step is 36
# 36/105, Train_loss: 0.3034
# Train_dice: 0.6966
# Train step is 37
# 37/105, Train_loss: 0.3997
# Train_dice: 0.6003
# Train step is 38
# 38/105, Train_loss: 0.3597
# Train_dice: 0.6403
# Train step is 39
# 39/105, Train_loss: 0.3717
# Train_dice: 0.6283
# Train step is 40
# 40/105, Train_loss: 0.3894
# Train_dice: 0.6106
# Train step is 41
# 41/105, Train_loss: 0.4734
# Train_dice: 0.5266
# Train step is 42
# 42/105, Train_loss: 0.3659
# Train_dice: 0.6341
# Train step is 43
# 43/105, Train_loss: 0.3630
# Train_dice: 0.6370
# Train step is 44
# 44/105, Train_loss: 0.3888
# Train_dice: 0.6112
# Train step is 45
# 45/105, Train_loss: 0.3683
# Train_dice: 0.6317
# Train step is 46
# 46/105, Train_loss: 0.3528
# Train_dice: 0.6472
# Train step is 47
# 47/105, Train_loss: 0.3593
# Train_dice: 0.6407
# Train step is 48
# 48/105, Train_loss: 0.4906
# Train_dice: 0.5094
# Train step is 49
# 49/105, Train_loss: 0.4769
# Train_dice: 0.5231
# Train step is 50
# 50/105, Train_loss: 0.4917
# Train_dice: 0.5083
# Train step is 51
# 51/105, Train_loss: 0.5129
# Train_dice: 0.4871
# Train step is 52
# 52/105, Train_loss: 0.5061
# Train_dice: 0.4939
# Train step is 53
# 53/105, Train_loss: 0.5051
# Train_dice: 0.4949
# Train step is 54
# 54/105, Train_loss: 0.5089
# Train_dice: 0.4911
# Train step is 55
# 55/105, Train_loss: 0.5109
# Train_dice: 0.4891
# Train step is 56
# 56/105, Train_loss: 0.4852
# Train_dice: 0.5148
# Train step is 57
# 57/105, Train_loss: 0.4730
# Train_dice: 0.5270
# Train step is 58
# 58/105, Train_loss: 0.4290
# Train_dice: 0.5710
# Train step is 59
# 59/105, Train_loss: 0.4561
# Train_dice: 0.5439
# Train step is 60
# 60/105, Train_loss: 0.4328
# Train_dice: 0.5672
# Train step is 61
# 61/105, Train_loss: 0.4636
# Train_dice: 0.5364
# Train step is 62
# 62/105, Train_loss: 0.4634
# Train_dice: 0.5366
# Train step is 63
# 63/105, Train_loss: 0.4814
# Train_dice: 0.5186
# Train step is 64
# 64/105, Train_loss: 0.4602
# Train_dice: 0.5398
# Train step is 65
# 65/105, Train_loss: 0.4715
# Train_dice: 0.5285
# Train step is 66
# 66/105, Train_loss: 0.4586
# Train_dice: 0.5414
# Train step is 67
# 67/105, Train_loss: 0.4736
# Train_dice: 0.5264
# Train step is 68
# 68/105, Train_loss: 0.4373
# Train_dice: 0.5627
# Train step is 69
# 69/105, Train_loss: 0.4727
# Train_dice: 0.5273
# Train step is 70
# 70/105, Train_loss: 0.4505
# Train_dice: 0.5495
# Train step is 71
# 71/105, Train_loss: 0.4718
# Train_dice: 0.5282
# Train step is 72
# 72/105, Train_loss: 0.4915
# Train_dice: 0.5085
# Train step is 73
# 73/105, Train_loss: 0.4710
# Train_dice: 0.5290
# Train step is 74
# 74/105, Train_loss: 0.4849
# Train_dice: 0.5151
# Train step is 75
# 75/105, Train_loss: 0.4614
# Train_dice: 0.5386
# Train step is 76
# 76/105, Train_loss: 0.4281
# Train_dice: 0.5719
# Train step is 77
# 77/105, Train_loss: 0.3940
# Train_dice: 0.6060
# Train step is 78
# 78/105, Train_loss: 0.4854
# Train_dice: 0.5146
# Train step is 79
# 79/105, Train_loss: 0.4598
# Train_dice: 0.5402
# Train step is 80
# 80/105, Train_loss: 0.4566
# Train_dice: 0.5434
# Train step is 81
# 81/105, Train_loss: 0.4377
# Train_dice: 0.5623
# Train step is 82
# 82/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 83
# 83/105, Train_loss: 0.4796
# Train_dice: 0.5204
# Train step is 84
# 84/105, Train_loss: 0.4999
# Train_dice: 0.5001
# Train step is 85
# 85/105, Train_loss: 0.4818
# Train_dice: 0.5182
# Train step is 86
# 86/105, Train_loss: 0.4614
# Train_dice: 0.5386
# Train step is 87
# 87/105, Train_loss: 0.4563
# Train_dice: 0.5437
# Train step is 88
# 88/105, Train_loss: 0.4187
# Train_dice: 0.5813
# Train step is 89
# 89/105, Train_loss: 0.5061
# Train_dice: 0.4939
# Train step is 90
# 90/105, Train_loss: 0.4591
# Train_dice: 0.5409
# Train step is 91
# 91/105, Train_loss: 0.4114
# Train_dice: 0.5886
# Train step is 92
# 92/105, Train_loss: 0.4489
# Train_dice: 0.5511
# Train step is 93
# 93/105, Train_loss: 0.5035
# Train_dice: 0.4965
# Train step is 94
# 94/105, Train_loss: 0.5028
# Train_dice: 0.4972
# Train step is 95
# 95/105, Train_loss: 0.5000
# Train_dice: 0.5000
# Train step is 96
# 96/105, Train_loss: 0.4943
# Train_dice: 0.5057
# Train step is 97
# 97/105, Train_loss: 0.4956
# Train_dice: 0.5044
# Train step is 98
# 98/105, Train_loss: 0.5037
# Train_dice: 0.4963
# Train step is 99
# 99/105, Train_loss: 0.5001
# Train_dice: 0.4999
# Train step is 100
# 100/105, Train_loss: 0.4667
# Train_dice: 0.5333
# Train step is 101
# 101/105, Train_loss: 0.5126
# Train_dice: 0.4874
# Train step is 102
# 102/105, Train_loss: 0.4932
# Train_dice: 0.5068
# Train step is 103
# 103/105, Train_loss: 0.4403
# Train_dice: 0.5597
# Train step is 104
# 104/105, Train_loss: 0.4487
# Train_dice: 0.5513
# Train step is 105
# 105/105, Train_loss: 0.4619
# Train_dice: 0.5381
# Train step is 106
# 106/105, Train_loss: 0.4711
# Train_dice: 0.5289
# --------------------
# Epoch_loss: 0.4534
# Epoch_metric: 0.5372
# test_loss_epoch: 0.5203
# test_dice_epoch: 0.5227
# current epoch: 7 current mean dice: 0.5631
# best mean dice: 0.5227 at epoch: 7
# ----------
# epoch 8/10
# Train step is 2
# 2/105, Train_loss: 0.4348
# Train_dice: 0.5652
# Train step is 3
# 3/105, Train_loss: 0.4835
# Train_dice: 0.5165
# Train step is 4
# ...
# Train_dice: 0.5344
# Train step is 74
# 74/105, Train_loss: 0.4795
# Train_dice: 0.5205
# Train step is 75
# 75/105, Train_loss: 0.4559
# Train_dice: 0.5441
# Train step is 76
# 76/105, Train_loss: 0.4218
# Train_dice: 0.5782
# Train step is 77
# 77/105, Train_loss: 0.3868
# Train_dice: 0.6132
# Train step is 78
# 78/105, Train_loss: 0.4805
# Train_dice: 0.5195
# Train step is 79
# 79/105, Train_loss: 0.4537
# Train_dice: 0.5463
# Train step is 80
# 80/105, Train_loss: 0.4510
# Train_dice: 0.5490
# Train step is 81
# 81/105, Train_loss: 0.4318
# Train_dice: 0.5682
# Train step is 82
# 82/105, Train_loss: 0.4691
# Train_dice: 0.5309
# Train step is 83
# 83/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 84
# 84/105, Train_loss: 0.4954
# Train_dice: 0.5046
# Train step is 85
# 85/105, Train_loss: 0.4765
# Train_dice: 0.5235
# Train step is 86
# 86/105, Train_loss: 0.4560
# Train_dice: 0.5440
# Train step is 87
# 87/105, Train_loss: 0.4504
# Train_dice: 0.5496
# Train step is 88
# 88/105, Train_loss: 0.4123
# Train_dice: 0.5877
# Train step is 89
# 89/105, Train_loss: 0.5017
# Train_dice: 0.4983
# Train step is 90
# 90/105, Train_loss: 0.4534
# Train_dice: 0.5466
# Train step is 91
# 91/105, Train_loss: 0.4047
# Train_dice: 0.5953
# Train step is 92
# 92/105, Train_loss: 0.4433
# Train_dice: 0.5567
# Train step is 93
# 93/105, Train_loss: 0.4989
# Train_dice: 0.5011
# Train step is 94
# 94/105, Train_loss: 0.4986
# Train_dice: 0.5014
# Train step is 95
# 95/105, Train_loss: 0.4955
# Train_dice: 0.5045
# Train step is 96
# 96/105, Train_loss: 0.4896
# Train_dice: 0.5104
# Train step is 97
# 97/105, Train_loss: 0.4910
# Train_dice: 0.5090
# Train step is 98
# 98/105, Train_loss: 0.4994
# Train_dice: 0.5006
# Train step is 99
# 99/105, Train_loss: 0.4957
# Train_dice: 0.5043
# Train step is 100
# 100/105, Train_loss: 0.4613
# Train_dice: 0.5387
# Train step is 101
# 101/105, Train_loss: 0.5086
# Train_dice: 0.4914
# Train step is 102
# 102/105, Train_loss: 0.4886
# Train_dice: 0.5114
# Train step is 103
# 103/105, Train_loss: 0.4347
# Train_dice: 0.5653
# Train step is 104
# 104/105, Train_loss: 0.4432
# Train_dice: 0.5568
# Train step is 105
# 105/105, Train_loss: 0.4565
# Train_dice: 0.5435
# Train step is 106
# 106/105, Train_loss: 0.4661
# Train_dice: 0.5339
# --------------------
# Epoch_loss: 0.4476
# Epoch_metric: 0.5429
# test_loss_epoch: 0.5183
# test_dice_epoch: 0.5275
# current epoch: 8 current mean dice: 0.5688
# best mean dice: 0.5275 at epoch: 8
# ----------
# epoch 9/10
# Train step is 2
# 2/105, Train_loss: 0.4290
# Train_dice: 0.5710
# Train step is 3
# 3/105, Train_loss: 0.4788
# Train_dice: 0.5212
# Train step is 4
# 4/105, Train_loss: 0.4718
# Train_dice: 0.5282
# Train step is 5
# 5/105, Train_loss: 0.4281
# Train_dice: 0.5719
# Train step is 6
# 6/105, Train_loss: 0.4184
# Train_dice: 0.5816
# Train step is 7
# 7/105, Train_loss: 0.4568
# Train_dice: 0.5432
# Train step is 8
# 8/105, Train_loss: 0.4921
# Train_dice: 0.5079
# Train step is 9
# 9/105, Train_loss: 0.4897
# Train_dice: 0.5103
# Train step is 10
# 10/105, Train_loss: 0.4627
# Train_dice: 0.5373
# Train step is 11
# 11/105, Train_loss: 0.4355
# Train_dice: 0.5645
# Train step is 12
# 12/105, Train_loss: 0.5067
# Train_dice: 0.4933
# Train step is 13
# 13/105, Train_loss: 0.4808
# Train_dice: 0.5192
# Train step is 14
# 14/105, Train_loss: 0.4729
# Train_dice: 0.5271
# Train step is 15
# 15/105, Train_loss: 0.4666
# Train_dice: 0.5334
# Train step is 16
# 16/105, Train_loss: 0.4816
# Train_dice: 0.5184
# Train step is 17
# 17/105, Train_loss: 0.5163
# Train_dice: 0.4837
# Train step is 18
# 18/105, Train_loss: 0.4529
# Train_dice: 0.5471
# Train step is 19
# 19/105, Train_loss: 0.4684
# Train_dice: 0.5316
# Train step is 20
# 20/105, Train_loss: 0.4584
# Train_dice: 0.5416
# Train step is 21
# 21/105, Train_loss: 0.4513
# Train_dice: 0.5487
# Train step is 22
# 22/105, Train_loss: 0.5351
# Train_dice: 0.4649
# Train step is 23
# 23/105, Train_loss: 0.4586
# Train_dice: 0.5414
# Train step is 24
# 24/105, Train_loss: 0.4541
# Train_dice: 0.5459
# Train step is 25
# 25/105, Train_loss: 0.4680
# Train_dice: 0.5320
# Train step is 26
# 26/105, Train_loss: 0.4907
# Train_dice: 0.5093
# Train step is 27
# 27/105, Train_loss: 0.4951
# Train_dice: 0.5049
# Train step is 28
# 28/105, Train_loss: 0.3189
# Train_dice: 0.6811
# Train step is 29
# 29/105, Train_loss: 0.4047
# Train_dice: 0.5953
# Train step is 30
# 30/105, Train_loss: 0.4754
# Train_dice: 0.5246
# Train step is 31
# 31/105, Train_loss: 0.3968
# Train_dice: 0.6032
# Train step is 32
# 32/105, Train_loss: 0.3916
# Train_dice: 0.6084
# Train step is 33
# 33/105, Train_loss: 0.3552
# Train_dice: 0.6448
# Train step is 34
# 34/105, Train_loss: 0.3748
# Train_dice: 0.6252
# Train step is 35
# 35/105, Train_loss: 0.3970
# Train_dice: 0.6030
# Train step is 36
# 36/105, Train_loss: 0.2877
# Train_dice: 0.7123
# Train step is 37
# 37/105, Train_loss: 0.3857
# Train_dice: 0.6143
# Train step is 38
# 38/105, Train_loss: 0.3452
# Train_dice: 0.6548
# Train step is 39
# 39/105, Train_loss: 0.3578
# Train_dice: 0.6422
# Train step is 40
# 40/105, Train_loss: 0.3748
# Train_dice: 0.6252
# Train step is 41
# 41/105, Train_loss: 0.4625
# Train_dice: 0.5375
# Train step is 42
# 42/105, Train_loss: 0.3511
# Train_dice: 0.6489
# Train step is 43
# 43/105, Train_loss: 0.3473
# Train_dice: 0.6527
# Train step is 44
# 44/105, Train_loss: 0.3748
# Train_dice: 0.6252
# Train step is 45
# 45/105, Train_loss: 0.3545
# Train_dice: 0.6455
# Train step is 46
# 46/105, Train_loss: 0.3384
# Train_dice: 0.6616
# Train step is 47
# 47/105, Train_loss: 0.3439
# Train_dice: 0.6561
# Train step is 48
# 48/105, Train_loss: 0.4814
# Train_dice: 0.5186
# Train step is 49
# 49/105, Train_loss: 0.4666
# Train_dice: 0.5334
# Train step is 50
# 50/105, Train_loss: 0.4817
# Train_dice: 0.5183
# Train step is 51
# 51/105, Train_loss: 0.5040
# Train_dice: 0.4960
# Train step is 52
# 52/105, Train_loss: 0.4974
# Train_dice: 0.5026
# Train step is 53
# 53/105, Train_loss: 0.4968
# Train_dice: 0.5032
# Train step is 54
# 54/105, Train_loss: 0.5007
# Train_dice: 0.4993
# Train step is 55
# 55/105, Train_loss: 0.5030
# Train_dice: 0.4970
# Train step is 56
# 56/105, Train_loss: 0.4756
# Train_dice: 0.5244
# Train step is 57
# 57/105, Train_loss: 0.4627
# Train_dice: 0.5373
# Train step is 58
# 58/105, Train_loss: 0.4173
# Train_dice: 0.5827
# Train step is 59
# 59/105, Train_loss: 0.4455
# Train_dice: 0.5545
# Train step is 60
# 60/105, Train_loss: 0.4209
# Train_dice: 0.5791
# Train step is 61
# 61/105, Train_loss: 0.4533
# Train_dice: 0.5467
# Train step is 62
# 62/105, Train_loss: 0.4526
# Train_dice: 0.5474
# Train step is 63
# 63/105, Train_loss: 0.4713
# Train_dice: 0.5287
# Train step is 64
# 64/105, Train_loss: 0.4497
# Train_dice: 0.5503
# Train step is 65
# 65/105, Train_loss: 0.4612
# Train_dice: 0.5388
# Train step is 66
# 66/105, Train_loss: 0.4474
# Train_dice: 0.5526
# Train step is 67
# 67/105, Train_loss: 0.4635
# Train_dice: 0.5365
# Train step is 68
# 68/105, Train_loss: 0.4259
# Train_dice: 0.5741
# Train step is 69
# 69/105, Train_loss: 0.4621
# Train_dice: 0.5379
# Train step is 70
# 70/105, Train_loss: 0.4398
# Train_dice: 0.5602
# Train step is 71
# 71/105, Train_loss: 0.4625
# Train_dice: 0.5375
# Train step is 72
# 72/105, Train_loss: 0.4824
# Train_dice: 0.5176
# Train step is 73
# 73/105, Train_loss: 0.4608
# Train_dice: 0.5392
# Train step is 74
# 74/105, Train_loss: 0.4748
# Train_dice: 0.5252
# Train step is 75
# 75/105, Train_loss: 0.4510
# Train_dice: 0.5490
# Train step is 76
# 76/105, Train_loss: 0.4160
# Train_dice: 0.5840
# Train step is 77
# 77/105, Train_loss: 0.3807
# Train_dice: 0.6193
# Train step is 78
# 78/105, Train_loss: 0.4762
# Train_dice: 0.5238
# Train step is 79
# 79/105, Train_loss: 0.4485
# Train_dice: 0.5515
# Train step is 80
# 80/105, Train_loss: 0.4461
# Train_dice: 0.5539
# Train step is 81
# 81/105, Train_loss: 0.4266
# Train_dice: 0.5734
# Train step is 82
# 82/105, Train_loss: 0.4643
# Train_dice: 0.5357
# Train step is 83
# 83/105, Train_loss: 0.4703
# Train_dice: 0.5297
# Train step is 84
# 84/105, Train_loss: 0.4914
# Train_dice: 0.5086
# Train step is 85
# 85/105, Train_loss: 0.4720
# Train_dice: 0.5280
# Train step is 86
# 86/105, Train_loss: 0.4514
# Train_dice: 0.5486
# Train step is 87
# 87/105, Train_loss: 0.4455
# Train_dice: 0.5545
# Train step is 88
# 88/105, Train_loss: 0.4066
# Train_dice: 0.5934
# Train step is 89
# 89/105, Train_loss: 0.4978
# Train_dice: 0.5022
# Train step is 90
# 90/105, Train_loss: 0.4484
# Train_dice: 0.5516
# Train step is 91
# 91/105, Train_loss: 0.3988
# Train_dice: 0.6012
# Train step is 92
# 92/105, Train_loss: 0.4385
# Train_dice: 0.5615
# Train step is 93
# 93/105, Train_loss: 0.4948
# Train_dice: 0.5052
# Train step is 94
# 94/105, Train_loss: 0.4948
# Train_dice: 0.5052
# Train step is 95
# 95/105, Train_loss: 0.4915
# Train_dice: 0.5085
# Train step is 96
# 96/105, Train_loss: 0.4853
# Train_dice: 0.5147
# Train step is 97
# 97/105, Train_loss: 0.4869
# Train_dice: 0.5131
# Train step is 98
# 98/105, Train_loss: 0.4956
# Train_dice: 0.5044
# Train step is 99
# 99/105, Train_loss: 0.4917
# Train_dice: 0.5083
# Train step is 100
# 100/105, Train_loss: 0.4566
# Train_dice: 0.5434
# Train step is 101
# 101/105, Train_loss: 0.5049
# Train_dice: 0.4951
# Train step is 102
# 102/105, Train_loss: 0.4844
# Train_dice: 0.5156
# Train step is 103
# 103/105, Train_loss: 0.4296
# Train_dice: 0.5704
# Train step is 104
# 104/105, Train_loss: 0.4382
# Train_dice: 0.5618
# Train step is 105
# 105/105, Train_loss: 0.4518
# Train_dice: 0.5482
# Train step is 106
# 106/105, Train_loss: 0.4617
# Train_dice: 0.5383
# --------------------
# Epoch_loss: 0.4426
# Epoch_metric: 0.5479
# test_loss_epoch: 0.5167
# test_dice_epoch: 0.5318
# current epoch: 9 current mean dice: 0.5741
# best mean dice: 0.5318 at epoch: 9
# ----------
# epoch 10/10
# Train step is 2
# 2/105, Train_loss: 0.4240
# Train_dice: 0.5760
# Train step is 3
# 3/105, Train_loss: 0.4746
# Train_dice: 0.5254
# Train step is 4
# 4/105, Train_loss: 0.4674
# Train_dice: 0.5326
# Train step is 5
# 5/105, Train_loss: 0.4228
# Train_dice: 0.5772
# Train step is 6
# 6/105, Train_loss: 0.4129
# Train_dice: 0.5871
# Train step is 7
# 7/105, Train_loss: 0.4521
# Train_dice: 0.5479
# Train step is 8
# 8/105, Train_loss: 0.4882
# Train_dice: 0.5118
# Train step is 9
# 9/105, Train_loss: 0.4856
# Train_dice: 0.5144
# Train step is 10
# 10/105, Train_loss: 0.4582
# Train_dice: 0.5418
# Train step is 11
# 11/105, Train_loss: 0.4305
# Train_dice: 0.5695
# Train step is 12
# 12/105, Train_loss: 0.5031
# Train_dice: 0.4969
# Train step is 13
# 13/105, Train_loss: 0.4767
# Train_dice: 0.5233
# Train step is 14
# 14/105, Train_loss: 0.4685
# Train_dice: 0.5315
# Train step is 15
# 15/105, Train_loss: 0.4623
# Train_dice: 0.5377
# Train step is 16
# 16/105, Train_loss: 0.4774
# Train_dice: 0.5226
# Train step is 17
# 17/105, Train_loss: 0.5129
# Train_dice: 0.4871
# Train step is 18
# 18/105, Train_loss: 0.4482
# Train_dice: 0.5518
# Train step is 19
# 19/105, Train_loss: 0.4640
# Train_dice: 0.5360
# Train step is 20
# 20/105, Train_loss: 0.4539
# Train_dice: 0.5461
# Train step is 21
# 21/105, Train_loss: 0.4467
# Train_dice: 0.5533
# Train step is 22
# 22/105, Train_loss: 0.5321
# Train_dice: 0.4679
# Train step is 23
# 23/105, Train_loss: 0.4540
# Train_dice: 0.5460
# Train step is 24
# 24/105, Train_loss: 0.4494
# Train_dice: 0.5506
# Train step is 25
# 25/105, Train_loss: 0.4635
# Train_dice: 0.5365
# Train step is 26
# 26/105, Train_loss: 0.4870
# Train_dice: 0.5130
# Train step is 27
# 27/105, Train_loss: 0.4915
# Train_dice: 0.5085
# Train step is 28
# 28/105, Train_loss: 0.3129
# Train_dice: 0.6871
# Train step is 29
# 29/105, Train_loss: 0.3993
# Train_dice: 0.6007
# Train step is 30
# 30/105, Train_loss: 0.4712
# Train_dice: 0.5288
# Train step is 31
# 31/105, Train_loss: 0.3912
# Train_dice: 0.6088
# Train step is 32
# 32/105, Train_loss: 0.3863
# Train_dice: 0.6137
# Train step is 33
# 33/105, Train_loss: 0.3491
# Train_dice: 0.6509
# Train step is 34
# 34/105, Train_loss: 0.3693
# Train_dice: 0.6307
# Train step is 35
# 35/105, Train_loss: 0.3908
# Train_dice: 0.6092
# Train step is 36
# 36/105, Train_loss: 0.2811
# Train_dice: 0.7189
# Train step is 37
# 37/105, Train_loss: 0.3803
# Train_dice: 0.6197
# Train step is 38
# 38/105, Train_loss: 0.3392
# Train_dice: 0.6608
# Train step is 39
# 39/105, Train_loss: 0.3522
# Train_dice: 0.6478
# Train step is 40
# 40/105, Train_loss: 0.3687
# Train_dice: 0.6313
# Train step is 41
# 41/105, Train_loss: 0.4581
# Train_dice: 0.5419
# Train step is 42
# 42/105, Train_loss: 0.3455
# Train_dice: 0.6545
# Train step is 43
# 43/105, Train_loss: 0.3418
# Train_dice: 0.6582
# Train step is 44
# 44/105, Train_loss: 0.3690
# Train_dice: 0.6310
# Train step is 45
# 45/105, Train_loss: 0.3484
# Train_dice: 0.6516
# Train step is 46
# 46/105, Train_loss: 0.3328
# Train_dice: 0.6672
# Train step is 47
# 47/105, Train_loss: 0.3381
# Train_dice: 0.6619
# Train step is 48
# 48/105, Train_loss: 0.4776
# Train_dice: 0.5224
# Train step is 49
# 49/105, Train_loss: 0.4625
# Train_dice: 0.5375
# Train step is 50
# 50/105, Train_loss: 0.4778
# Train_dice: 0.5222
# Train step is 51
# 51/105, Train_loss: 0.5003
# Train_dice: 0.4997
# Train step is 52
# 52/105, Train_loss: 0.4937
# Train_dice: 0.5063
# Train step is 53
# 53/105, Train_loss: 0.4933
# Train_dice: 0.5067
# Train step is 54
# 54/105, Train_loss: 0.4972
# Train_dice: 0.5028
# Train step is 55
# 55/105, Train_loss: 0.4996
# Train_dice: 0.5004
# Train step is 56
# 56/105, Train_loss: 0.4715
# Train_dice: 0.5285
# Train step is 57
# 57/105, Train_loss: 0.4584
# Train_dice: 0.5416
# Train step is 58
# 58/105, Train_loss: 0.4119
# Train_dice: 0.5881
# Train step is 59
# 59/105, Train_loss: 0.4412
# Train_dice: 0.5588
# Train step is 60
# 60/105, Train_loss: 0.4159
# Train_dice: 0.5841
# Train step is 61
# 61/105, Train_loss: 0.4491
# Train_dice: 0.5509
# Train step is 62
# 62/105, Train_loss: 0.4481
# Train_dice: 0.5519
# Train step is 63
# 63/105, Train_loss: 0.4671
# Train_dice: 0.5329
# Train step is 64
# 64/105, Train_loss: 0.4452
# Train_dice: 0.5548
# Train step is 65
# 65/105, Train_loss: 0.4570
# Train_dice: 0.5430
# Train step is 66
# 66/105, Train_loss: 0.4431
# Train_dice: 0.5569
# Train step is 67
# 67/105, Train_loss: 0.4594
# Train_dice: 0.5406
# Train step is 68
# 68/105, Train_loss: 0.4210
# Train_dice: 0.5790
# Train step is 69
# 69/105, Train_loss: 0.4577
# Train_dice: 0.5423
# Train step is 70
# 70/105, Train_loss: 0.4354
# Train_dice: 0.5646
# Train step is 71
# 71/105, Train_loss: 0.4585
# Train_dice: 0.5415
# Train step is 72
# 72/105, Train_loss: 0.4787
# Train_dice: 0.5213
# Train step is 73
# 73/105, Train_loss: 0.4566
# Train_dice: 0.5434
# Train step is 74
# 74/105, Train_loss: 0.4707
# Train_dice: 0.5293
# Train step is 75
# 75/105, Train_loss: 0.4465
# Train_dice: 0.5535
# Train step is 76
# 76/105, Train_loss: 0.4109
# Train_dice: 0.5891
# Train step is 77
# 77/105, Train_loss: 0.3749
# Train_dice: 0.6251
# Train step is 78
# 78/105, Train_loss: 0.4722
# Train_dice: 0.5278
# Train step is 79
# 79/105, Train_loss: 0.4437
# Train_dice: 0.5563
# Train step is 80
# 80/105, Train_loss: 0.4418
# Train_dice: 0.5582
# Train step is 81
# 81/105, Train_loss: 0.4222
# Train_dice: 0.5778
# Train step is 82
# 82/105, Train_loss: 0.4602
# Train_dice: 0.5398
# Train step is 83
# 83/105, Train_loss: 0.4663
# Train_dice: 0.5337
# Train step is 84
# 84/105, Train_loss: 0.4878
# Train_dice: 0.5122
# Train step is 85
# 85/105, Train_loss: 0.4681
# Train_dice: 0.5319
# Train step is 86
# 86/105, Train_loss: 0.4472
# Train_dice: 0.5528
# Train step is 87
# 87/105, Train_loss: 0.4412
# Train_dice: 0.5588
# Train step is 88
# 88/105, Train_loss: 0.4012
# Train_dice: 0.5988
# Train step is 89
# 89/105, Train_loss: 0.4940
# Train_dice: 0.5060
# Train step is 90
# 90/105, Train_loss: 0.4440
# Train_dice: 0.5560
# Train step is 91
# 91/105, Train_loss: 0.3935
# Train_dice: 0.6065
# Train step is 92
# 92/105, Train_loss: 0.4340
# Train_dice: 0.5660
# Train step is 93
# 93/105, Train_loss: 0.4912
# Train_dice: 0.5088
# Train step is 94
# 94/105, Train_loss: 0.4912
# Train_dice: 0.5088
# Train step is 95
# 95/105, Train_loss: 0.4877
# Train_dice: 0.5123
# Train step is 96
# 96/105, Train_loss: 0.4815
# Train_dice: 0.5185
# Train step is 97
# 97/105, Train_loss: 0.4832
# Train_dice: 0.5168
# Train step is 98
# 98/105, Train_loss: 0.4921
# Train_dice: 0.5079
# Train step is 99
# 99/105, Train_loss: 0.4881
# Train_dice: 0.5119
# Train step is 100
# 100/105, Train_loss: 0.4523
# Train_dice: 0.5477
# Train step is 101
# 101/105, Train_loss: 0.5016
# Train_dice: 0.4984
# Train step is 102
# 102/105, Train_loss: 0.4806
# Train_dice: 0.5194
# Train step is 103
# 103/105, Train_loss: 0.4252
# Train_dice: 0.5748
# Train step is 104
# 104/105, Train_loss: 0.4335
# Train_dice: 0.5665
# Train step is 105
# 105/105, Train_loss: 0.4475
# Train_dice: 0.5525
# Train step is 106
# 106/105, Train_loss: 0.4576
# Train_dice: 0.5424
# --------------------
# Epoch_loss: 0.4382
# Epoch_metric: 0.5524
# test_loss_epoch: 0.5156
# test_dice_epoch: 0.5357
# current epoch: 10 current mean dice: 0.5797
# best mean dice: 0.5357 at epoch: 10
# train completed, best_metric: 0.5357 at epoch: 10
